# %% [markdown]
# <a href="https://colab.research.google.com/github/ruchitha003/unp-project/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
import io
data=io.BytesIO(uploaded['winequality-red.csv'])
wr_data=pd.read_csv(data,sep=';')
print(wr_data)
print(wr_data.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ce17c6715145> in <module>()
#       1 import io
# ----> 2 data=io.BytesIO(uploaded['winequality-red.csv'])
#       3 wr_data=pd.read_csv(data,sep=';')
#       4 print(wr_data)
#       5 print(wr_data.shape)
#
# NameError: name 'uploaded' is not defined

# %%
wr_data['quality']
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1599, dtype: int64

# %%
wr_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
wr_data.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
wr_data.describe()
# Out:
#        fixed acidity  volatile acidity  ...      alcohol      quality
# count    1599.000000       1599.000000  ...  1599.000000  1599.000000
# mean        8.319637          0.527821  ...    10.422983     5.636023
# std         1.741096          0.179060  ...     1.065668     0.807569
# min         4.600000          0.120000  ...     8.400000     3.000000
# 25%         7.100000          0.390000  ...     9.500000     5.000000
# 50%         7.900000          0.520000  ...    10.200000     6.000000
# 75%         9.200000          0.640000  ...    11.100000     6.000000
# max        15.900000          1.580000  ...    14.900000     8.000000
#
# [8 rows x 12 columns]

# %%
wr_data['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
plt.figure(figsize = (12,6))
sns.countplot(wr_data['quality'])
plt.show()

# %%
plt.figure(figsize = (16,8))
sns.heatmap(wr_data.corr(), annot=True)
plt.title("correlation between the coloumns")
plt.show()

# %%
wr_data.corr()['quality'].sort_values()
# Out:
# volatile acidity       -0.390558
# total sulfur dioxide   -0.185100
# density                -0.174919
# chlorides              -0.128907
# pH                     -0.057731
# free sulfur dioxide    -0.050656
# residual sugar          0.013732
# fixed acidity           0.124052
# citric acid             0.226373
# sulphates               0.251397
# alcohol                 0.476166
# quality                 1.000000
# Name: quality, dtype: float64

# %%
plt.figure(figsize = (12,6))
sns.barplot(wr_data['quality'], wr_data['alcohol'])
plt.show()

# %%
plt.figure(figsize = (12,6))
sns.barplot(wr_data['quality'], wr_data['volatile acidity'])
plt.show()

# %%
plt.figure(figsize = (12,6))
sns.barplot(wr_data['quality'], wr_data['free sulfur dioxide'])
plt.show()

# %%
plt.figure(figsize = (12,6))
sns.barplot(wr_data['quality'], wr_data['residual sugar'])
plt.show()

# %%
wr_data['quality']
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1599, dtype: int64

# %%
wr_data['quality'] = wr_data.quality.apply(lambda x:1 if x>=5 else 0)

# %%
wr_data['quality'].value_counts()
# Out:
# 1    1536
# 0      63
# Name: quality, dtype: int64

# %%
X = wr_data.drop('quality', axis=1)
y = wr_data['quality']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=42)

# %%
print("X_train", X_train.shape)
print("y_train", y_train.shape)
print("X_test", X_test.shape)
print("y_test", y_test.shape)
# Out:
# X_train (1119, 11)
# y_train (1119,)
# X_test (480, 11)
# y_test (480,)

# %%
# Logistic Regression
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
logreg_pred = logreg.predict(X_test)
logreg_acc = accuracy_score(logreg_pred, y_test)
print("test accuracy is: {:.2f}%".format(logreg_acc*100))
# Out:
# test accuracy is: 96.25%

# %%
print(classification_report(y_test, logreg_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        18
#            1       0.96      1.00      0.98       462
#
#     accuracy                           0.96       480
#    macro avg       0.48      0.50      0.49       480
# weighted avg       0.93      0.96      0.94       480
